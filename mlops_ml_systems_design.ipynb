# %% [markdown]
# <a href="https://colab.research.google.com/github/beamscource/colab_notebooks/blob/main/mlops_ml_systems_design.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MLOps and ML systems

# %% [markdown]
# ## ML lifecycle

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Risk assesment**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## People of MLOps

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Model development

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Preparing for production**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Deploy to production**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Monitoring**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ML Systems book**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Building ML systems**
#
# https://stanford-cs329s.github.io/syllabus.html
#
# Downloaded versions with notes: https://drive.google.com/drive/u/0/folders/1gY4n4fHZtC85FTod6V5szSNdPYbmGCxD

# %% [markdown]
# **Lecture 1: Introduction**
#
# A ML algorithm is only a small part of an ML system in production. The system also includes the **interface** where users and developers interact with your system, the **data stack** to manage your data, the **hardware backend** your ML algorithm runs on, and the infrastructure to allow the system to be developed, deployed, monitored, and updated.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Because of the scale of many ML systems — they consume a massive amount of data, require heavy computational power, and have the potential to affect the lives of so many people — deploying them in production has many engineering and societal challenges.
#
# ML in production is very different from ML in research.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ML systems design process**
#
# Most ML systems should have these four characteristics: reliable, scalable, maintainable, and adaptable.
#
# *Reliability*
#
# The system should continue to perform the correct function at the desired level of performance even in the face of adversity (hardware or software faults, and even human error).
#
# “Correctness” might be difficult to determine for ML systems. For example, your system might call the function “.predict()” correctly, but the predictions are wrong.
#
# *Scalability*
#
# As the system grows (in data volume, traffic volume, or complexity), there should be reasonable ways of dealing with that growth.
#
# Scaling isn’t just up-scaling — expanding the resources to handle growth. In ML, it’s also important to down-scale — reducing the resources when not needed.
#
# *Maintainability*
#
# When a problem occurs, different contributors should be able to work together to identify the problem and implement a solution without finger-pointing.
#
# It’s important to structure your project and set up your infrastructure in a way such that different contributors can work using tools that they are comfortable with.
#
# *Adaptability*
#
# To adapt to changing data distributions and business requirements, the system should have some capacity for both discovering aspects for performance improvement and allowing updates without service interruption.
#
# Developing an ML system is an iterative and, in most cases, never ending process that resebles a cycle with many back-and-forths between single steps:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Lecture 2: Data engineering with raw data**

# %% [markdown]
# **Lecture 3: Sampling and labeling training data**

# %% [markdown]
# **Lecture 4: Data augmentation and feature engineering**

# %% [markdown]
# **Lecture 5: Model development**

# %% [markdown]
# **Lecture 6: Model evaluation**

# %% [markdown]
# **Lecture 7: Deployment**

# %% [markdown]
# **Performance monitoring**
