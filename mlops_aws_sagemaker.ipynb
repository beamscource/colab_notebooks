# %% [markdown]
# <a href="https://colab.research.google.com/github/beamscource/colab_notebooks/blob/main/mlops_aws_sagemaker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MLOps and ML systems

# %% [markdown]
# ## ML lifecycle

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Risk assesment**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## People of MLOps

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Model development

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # AWS SageMaker

# %% [markdown]
# ## Getting Started with AWS Free Tier
#
# 1. Go to https://aws.amazon.com/free/.
# 2. Click on 'Create your AWS Account'.
# 3. Follow the instructions to create your account.
#
# General tips for saving money: https://www.youtube.com/watch?v=Mgz9r7TtQlU

# %% [markdown]
# **Ressources**

# %% [markdown]
# - https://docs.aws.amazon.com/sagemaker/index.html
# - https://sagemaker-examples.readthedocs.io/en/latest/
# - https://github.com/vaquarkhan/AWS-Machine-Learning-Specialty

# %% [markdown]
# *SageMaker*
#
# Amazon SageMaker is a fully managed machine learning service. It provides an integrated Jupyter authoring notebook instance for easy access to your data sources for exploration and analysis, so you don't have to manage servers.
#
# It also provides common machine learning algorithms that are optimized to run efficiently against extremely large data in a distributed environment. With native support for bring-your-own-algorithms and frameworks, SageMaker offers flexible distributed training options that adjust to your specific workflows.
#
# Deploy a model into a secure and scalable environment by launching it with a few clicks from SageMaker Studio or the SageMaker console.
#
# Pricing: https://aws.amazon.com/sagemaker/pricing/ (There are some free ressources.)

# %% [markdown]
# *ML workflow on AWS*

# %% [markdown]
# The following diagram illustrates the typical workflow for creating a machine learning model:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In the ingest and analyze step, you explore the data and analyze the data for potential statistical bias.
#
# Looking at the toolbox for this step, you will use **Amazon Simple Storage Service (Amazon S3)** (https://aws.amazon.com/s3/faqs/) and **Amazon Athena** (https://aws.amazon.com/athena) to ingest, store, and query (SQL) your data.
#
# With **AWS Glue** (https://aws.amazon.com/glue), you will catalog the data in its schema (data pipelines).
#
# For statistical bias detection in data, you will learn how to work with **Amazon SageMaker Data Wrangler** (https://aws.amazon.com/sagemaker/data-wrangler - cleaning, transform, visualization, feature engineering) and **Amazon SageMaker Clarify** (https://aws.amazon.com/sagemaker/clarify/ - explore training data for bias, missing data, unbalanced data, feature importance).

# %% [markdown]
# You can use your notebook to fetch your dataset, explore it, and prepare it for model training. For more information, see https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-notebooks-instances.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# SageMaker enables developers to operate at a number of levels of abstraction when training and deploying machine learning models.
#
# At its highest level of abstraction, SageMaker provides **pre-trained ML models** that can be deployed as-is. In addition, SageMaker provides a number of **built-in ML algorithms** that developers can train on their own data. See https://docs.aws.amazon.com/sagemaker/latest/dg/algos.html
#
# Further, SageMaker provides **managed instances of PyTorch**, TensorFlow and Apache MXNet, where developers can create their **own ML models from scratch**. See https://docs.aws.amazon.com/sagemaker/latest/dg/frameworks.html and https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-training.html
#
# Regardless of which level of abstraction is used, a developer can connect their SageMaker-enabled ML models to other AWS services, such as the **Amazon DynamoDB database** for structured data storage (https://aws.amazon.com/blogs/big-data/analyze-data-in-amazon-dynamodb-using-amazon-sagemaker-for-real-time-prediction/), **AWS Batch for offline batch processing** (https://docs.aws.amazon.com/sagemaker/latest/dg/batch-transform.html) or **Amazon Kinesis for real-time processing** (https://aws.amazon.com/blogs/machine-learning/analyze-live-video-at-scale-in-real-time-using-amazon-kinesis-video-streams-and-amazon-sagemaker/).
#
# With **SageMaker hosting services**, you can deploy your model independently, decoupling it from your application code. For more information, see https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-deployment.html and https://docs.aws.amazon.com/sagemaker/latest/dg/deploy-model.html
#
# Machine learning is a continuous cycle. After deploying a model, you monitor the inferences, collect "ground truth," and evaluate the model to identify drift. You then increase the accuracy of your inferences by updating your training data to include the newly collected ground truth. You do this by retraining the model with the new dataset.

# %% [markdown]
# *Interacting with SageMaker*

# %% [markdown]
# See overview here https://docs.aws.amazon.com/sagemaker/latest/dg/gs.html

# %% [markdown]
# 1. Amazon **SageMaker Studio** is a web-based, integrated development environment (IDE) which provides all the tools you need to take your models from data preparation to experimentation to production.
#
# Studio offers teams (up to 8 members per domain) and companies easy on-boarding for their team members, freeing them up from complex systems admin and security processes.
#
# 2. **SageMaker Studio notebooks** are collaborative notebooks that you can launch quickly because you don't need to set up compute instances and file storage beforehand. A set of instance types, known as *Fast launch* types are designed to launch in under two minutes.
#
# Studio notebooks provide persistent storage, which enables you to view and share notebooks even if the instances that the notebooks run on are shut down.
#
# They have the familiar Jupyter and JuypterLab interfaces that work well for single users, or small teams where users are also administrators.
#
# 3. You can use a programmatic approach, employing **AWS CLI** (https://docs.aws.amazon.com/cli/latest/reference/sagemaker/index.html#cli-aws-sagemaker and https://docs.aws.amazon.com/cli/v1/userguide/cli-chap-install.html#install-tool-bundled), and **boto3 client** (https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/sagemaker.html), or the **Python SDK** (https://sagemaker.readthedocs.io/en/stable/).
#
# 4. Finally, you can run SageMaker from **Kubeflow pipelines** (https://docs.aws.amazon.com/sagemaker/latest/dg/kubernetes-sagemaker-components-for-kubeflow-pipelines.html) or from Kubernetes instances. But who is crazy enough to do this?

# %% [markdown]
# *Domain*
#
# To use SageMaker Studio, you have to register a domain. A domain consists of an associated **Amazon Elastic File System (EFS) volume**, a list of authorized users, and a variety of security, application, policy, and Amazon Virtual Private Cloud (VPC) configurations.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Follow best practices to set up the administrator user https://docs.aws.amazon.com/sagemaker/latest/dg/gs-set-up.html which you'll also need when working with programmatic tools.

# %% [markdown]
# *Notebook instances with VSCode*
#
# Notebook instances are much faster to lunch and are easier to use for single smaller projects.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When creating an instance, you can choose between standard, memory-optimized, compute-optimized, and acceleration-optimized environments.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can create **Lifecycle configurations** for each instance to create and start the instance. See an example here https://gist.github.com/juliensimon/4eccabf58fa2d97a294d181a525b0127
#
# Using the lifecycle configuration, we can download additional software on the notebook instance. For instance, instead of the default Jupyter, you can also run VSCode within a notebook.
#
# See details of how to set this up here https://www.youtube.com/watch?v=WSaTtqo2zfU&ab_channel=JulienSimon

# %% [markdown]
# *AWS CLI vs boto3 vs SageMaker Python SDK*
#
# The AWS CLI is a command-line tools which allows to connect things through shell scripts (e.g., copy files from S3 buckets).
#
# The SageMaker Python SDK is an open-source library that was developed specifically for training and deploying models on SageMaker. The package is meant to simplify different ML processes on Amazon SageMaker.
#
# The Boto3 SDK on the other hand is the general Python SDK for AWS. You can use this SDK to interact with any AWS service outside of SageMaker as well.
#
# See for examples https://towardsdatascience.com/sagemaker-python-sdk-vs-boto3-sdk-45c424e8e250

# %% [markdown]
# *Data ingestion*

# %% [markdown]
# **AWS Data Wrangler** is built on top of other open-source projects such as Pandas, Apache Arrow and Boto3. This offers abstracted functions to execute usual ETL tasks like load/unload data from Data Lakes, Data Warehouses and Databases using python.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Data pipelines are categorized into **distributed** and **non-distributed** pipelines.
#
# AWS Data Wrangler was created with the use case of building lightweight, non-distributed pipelines. So if perhaps you only need to work with thousands or hundreds of thousands of records then AWS Data wrangler may actually be a great use case for you.
#
# Now if you're working with billions of records, AWS data wrangler perhaps is not for your use case and you should look into building a distributed data pipeline potentially with **Pyspark** instead.
#
# The abstracted functions handle the data extraction and load steps in Python. This enables you to focus on the transformation step of ETL by using familiar pandas transformation and commands. Read more details here https://github.com/awslabs/aws-data-wrangler
#
# For more infos on how Data Wrangler interacts with other AWS services see https://python.plainenglish.io/reading-and-writing-data-in-aws-with-python-just-got-a-lot-simpler-55c5fcaab4c5

# %% [markdown]
# **Amazon SageMaker Data Wrangler** is a SageMaker Studio feature that has a similar name but a different purpose.
#
# With SageMaker Data Wrangler, you can simplify the process of data preparation and feature engineering, and complete each step of the data preparation workflow, including data selection, cleansing, exploration, and visualization from a single visual interface. Using the data selection tool, you can choose the data you want from various data sources and import it with a single click.
#
# Once data is imported, you can use the data quality and insights report to automatically verify data quality and detect abnormalities, such as duplicate rows and target leakage. SageMaker Data Wrangler contains over 300 built-in data transformations so you can quickly normalize, transform, and combine features without having to write any code.
#
# With SageMaker Data Wrangler’s visualization templates, you can quickly preview and inspect that these transformations are completed as you intended by viewing them in Amazon SageMaker Studio. Once your data is prepared, you can build fully automated ML workflows with **Amazon SageMaker Pipelines** and save them for reuse in the **Amazon SageMaker Feature Store**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# For more infos see https://catalog.us-east-1.prod.workshops.aws/workshops/327375b8-425b-49d4-b0da-241da0595ecf/en-US

# %% [markdown]
# *Feature Engineering with SageMaker Feature Store*

# %% [markdown]
# Amazon SageMaker Feature Store is a fully managed, purpose-built repository to store, share, and manage features for ML models.
#
# You can ingest different types of data into SageMaker Feature Store, including streaming data from sources such as application and service logs, clickstreams and sensors, and tabular data from sources such as Amazon S3, Amazon Redshift, AWS Lake Formation, Snowflake, and Databricks Delta Lake.
#
# With Amazon SageMaker Data Wrangler you can publish features directly into SageMaker Feature Store.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# SageMaker Feature Store tags and indexes feature groups so they are easily discoverable through the visual interface of Amazon SageMaker Studio. Browsing the feature catalog allows teams to discover existing features they can confidently reuse and avoid duplication of pipelines.
#
# SageMaker Feature Store uses the AWS Glue Data Catalog by default, but allows you to use a different catalog if desired. You can also query features using familiar SQL with Amazon Athena or another query tool of your choice.
#
# Find more details under
# - https://aws.amazon.com/sagemaker/feature-store
# - https://aws.amazon.com/glue
# - https://aws.amazon.com/athena/

# %% [markdown]
# *Training a custom model with SageMaker and profile with Debugger*

# %% [markdown]
# https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-training.html

# %% [markdown]
# https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-prog-model.html

# %% [markdown]
# Amazon SageMaker Debugger automatically monitors utilization of system resources such as GPUs, CPUs, network, and memory, and profiles your training jobs to collect detailed ML framework metrics.
#
# You can inspect all resource metrics visually through SageMaker Studio. Anomalies in resource utilization are correlated to specific operations for identification of bottlenecks such as over-utilized CPUs so you can take corrective action quickly.
#
# Additionally, a detailed report can be downloaded for offline analysis. Training runs can be profiled either at the start of the training job or at any point when training is in progress.

# %% [markdown]
# Amazon SageMaker Debugger comes with built-in analytics that automatically analyze data emitted during training such as inputs, outputs, and transformations known as tensors. As a result, you can detect whether a model is overfitting or overtraining, whether gradients are getting too large or too small, whether GPU resources are underutilized, and other bottlenecks during training.
#
# With SageMaker Debugger, you can also create your own custom conditions to test for specific behavior in your training jobs. These conditions can invoke actions such as stopping a training job and sending an SMS or email.
#
# SageMaker Debugger supports ML frameworks including TensorFlow, PyTorch, Apache MXNet, Keras, and XGBoost. By default, SageMaker Debugger monitors system hardware utilization and losses during training without writing additional code to monitor each resource separately.

# %% [markdown]
# See more details at https://aws.amazon.com/sagemaker/debugger

# %% [markdown]
# https://docs.aws.amazon.com/sagemaker/latest/dg/pytorch.html

# %% [markdown]
# *ML pipelines with SageMaker*
#
# Using Amazon SageMaker Pipelines, you can create ML workflows with an easy-to-use Python SDK, and then visualize and manage your workflow using Amazon SageMaker Studio. You can be more efficient and scale faster by storing and reusing the workflow steps you create in SageMaker Pipelines. You can also get started quickly with built-in templates to build, test, register, and deploy models so you can get started with CI/CD in your ML environment quickly.
#
#
# See more details here https://aws.amazon.com/sagemaker/pipelines

# %% [markdown]
# - https://medium.com/@manasnarkar/sagemaker-how-to-build-machine-learning-pipeline-f485071498dd
#
# - https://aws.amazon.com/de/blogs/machine-learning/building-automating-managing-and-scaling-ml-workflows-using-amazon-sagemaker-pipelines/
#
# - https://aws.amazon.com/de/blogs/machine-learning/build-a-ci-cd-pipeline-for-deploying-custom-machine-learning-models-using-aws-services/

# %% [markdown]
# *Sagemaker Projects*
#
# https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-projects.html

# %% [markdown]
# More details on SageMaker ML workflows https://docs.aws.amazon.com/sagemaker/latest/dg/workflows.html

# %% [markdown]
# *Model deployment*
#
# - https://docs.aws.amazon.com/sagemaker/latest/dg/deploy-model.html

# %% [markdown]
# *Model and data-drift monitoring*
#
# - https://aws.amazon.com/sagemaker/model-monitor/
# - https://aws.amazon.com/sagemaker/clarify

# %% [markdown]
# *Data labeling with Amazon Augmented*
#
# https://docs.aws.amazon.com/sagemaker/latest/dg/sms.html

# %% [markdown]
# *Human-in-the-loop pipeline with Amazon Augmented*
#
# https://aws.amazon.com/augmented-ai

# %% [markdown]
# *SageMakers features*
#
# For a complete list of SageMaker'S features see https://docs.aws.amazon.com/sagemaker/latest/dg/whatis-features-alpha.html

# %% [markdown]
# *HuggingFace models on AWS*
#
# - https://aws.amazon.com/blogs/machine-learning/announcing-managed-inference-for-hugging-face-models-in-amazon-sagemaker/
# - https://docs.aws.amazon.com/sagemaker/latest/dg/hugging-face.html

# %% [markdown]
# https://pythonrepo.com/repo/thoughtworks-mlops-platforms-python-machine-learning

# %% [markdown]
# # Weights and Biases MLOps course

# %% [markdown]
# https://www.wandb.courses/courses/take/effective-mlops-model-development/lessons/40025747-welcome-to-the-course

# %% [markdown]
# *Weights and Biases*

# %% [markdown]
# You can get started in 3 steps:

# %%
# !python -m pip install wandb


import wandb
wandb.init() # connects the training run to the wandb server
# store hardware specifications and hyperparameters automatically

for epoch in range(hum_epochs):
  for i, batch in enumerate(dataloader):

    # model training

    wandb.log(...) # training metrics are stored
