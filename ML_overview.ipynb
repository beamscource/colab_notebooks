# %% [markdown]
# <a href="https://colab.research.google.com/github/beamscource/colab_notebooks/blob/main/ML_overview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sources

# %% [markdown]
# **Introductory books**
#
# - *“Understanding Machine Learning: from Theory to Algorithms”* by Shalev-Shwartz and Ben-David (Free, medium-difficulty, medium-depth)
# - *“Pattern Recognition And Machine Learning”* by Bishop (medium-difficulty, high-depth)
# - *“Machine Learning — A Probabilistic Perspective”* by Murphy (Free, high-difficulty, high-depth)
# - *“An Introduction to Statistical Learning (with Applications in R)”* by James, Witten, Hastie and Tibshirani (Free, low-difficulty, low-depth)
# - *“The Elements of Statistical Learning”* by Hastie, Tibshirani, Friedman (Free, high-difficulty, high-depth)

# %% [markdown]
# **Courses**
#
# - https://cs229.stanford.edu/ "This course provides a broad introduction to machine learning and statistical pattern recognition. Topics include: supervised learning (**generative/discriminative learning, parametric/non-parametric learning, neural networks, support vector machines**); unsupervised learning (**clustering, dimensionality reduction, kernel methods**); learning theory (**bias/variance tradeoffs**, practical advice); reinforcement learning and adaptive control."
#
# - https://de.coursera.org/learn/machine-learning-course "A classic but actually not that didactically usefull."
#   - cost function and gradient descend, linear regression, matrix multiplication and vectors, multivariative linear regression, classification and desicion boundary, non-linear hypotheses, multiclass classification, backpropagation, bias/variance, kernels and Support Vector Machines, unsupervised learning, anamoly detection, mini-batch/stochastic gradient descend, online learning, mapReduce, OCR

# %% [markdown]
# **Youtube playlists**
#
# - StatQuest (2018): https://www.youtube.com/watch?v=Gv9_4yMHFhI&list=PLblh5JKOoLUICTaGLRoHQDuF_7q2GfuJF
#   - cross validation, confusion matrix, precision/recall, bias/variance, entropy, **linear regression** (t-tests, ANOVA, design matrices), **ROC and AUC**, odds ratios, logistic regression, residuals, L1 and L2 regularization, **Principal Component Analysis** (with Python), **Linear Discriminant Analysis**, **t-SNE**, **MDS and PCoA**, **k-Means clustering**, **k-nearest neighbor**s, Gausian Naive Bayes, desicion trees, regression trees, **random forests**, gradient descent, **AdaBoost**, **Gradient boost**, **XGBoost**, **Support vector machines**, Neural networs
#   - way to many topics that are packed into a single list
#   - good for understanding classical ML algorithms
#
# - Nando de Freitas (Undergraduate, 2012): ML & Data Mining https://www.youtube.com/watch?v=pid0lUH467o&list=PLE6Wd9FR--Ecf_5nCbnSQMHqORpiChfJf
#   - intro to learning, Probability, Linear Algebra, Bayes, **Bayesian networks (Propabalistic graphical models)** and dynamic programming, **HMMs**, Bernoulli models, **Maximum likelihood**, Bayesian learning, **Single Value decomposition**, **Principal Component Analysis**, Least Squares, Linear prediction, cross-validation, L1 regularization, sparse models, Dirichlet, text classification and sentiment with Bayes, Optimization, logistic regression, NNs and backpropagation, decision trees, random forests
#   - all over the place and very basic, focus on older methods
#
# - Nando de Freitas (2013 version): https://www.youtube.com/watch?v=w2OtwL5T1ow&list=PLE6Wd9FR--EdyJ5lbFl8UuGjecvVw66F6
#   - a lot of overlap with previous course, unconstrained optimization, Markov Chain Monte Carlo, multi-armed bandits

# %% [markdown]
# NOTE: This notebook completely ignores neural networks as there is a specific notebook for this.

# %% [markdown]
# **Data sets**
#
# - https://archive-beta.ics.uci.edu/

# %% [markdown]
# General structure of the overview follows Chapter 5 of the Deep Learning book https://www.deeplearningbook.org/contents/ml.html

# %% [markdown]
# # General ideas and mechanics

# %% [markdown]
# **Machine learning** (ML) is essentially a form of applied statistics with increased emphasis on the use of computers to statistically **estimate complicated functions** and a decreased emphasis on proving confidence intervals around these functions.
#
# We combine various algorithm components such as an **optimization algorithm**, a **cost function**, a **model**, and a **dataset** to build a machine learning algorithm.

# %% [markdown]
# PICTURE

# %% [markdown]
# **Parts of a learning algorithm**
#
# A computer program is said to learn from **experience** *E* with respect to some class of **tasks** *T* and **performance measure** *P*, if its performance at tasks in *T*, as measured by *P*, improves with experience *E*.
#
# Machine learning tasks are usually described in terms of how the machine learning system should process an **example**. An example is a **collection of features** that have been quantitatively measured from some object or event that we want the machine learning system to process.
#
# We typically represent an example as a vector ***x***∈Rn where each entry *xi* of the vector is another feature.

# %% [markdown]
# **Features**
#
# The process of transducing examples to measurements can be called **feature extraction** (e.g., in NLP this could be tokenization and/or lemmatalization).
#
# Classical ML algorithms relied heavily on **feature engineering** (manual definitions of features), but Deep Learning made this process simpler, and is able to learn **feature representations** directly from the data (e.g., filters in computer vision or word-emmbeding vectors in NLP).
#
# Neural networks learn cascading representations which are not longer interpretable by a human but very useful for solving ML tasks.

# %% [markdown]
# PICTURE

# %% [markdown]
# **Experience:**
#
# ML algorithms can be divided into the categories of **supervised** learning and **unsupervised** learning.
#
#
# **Supervised learning** algorithms are allowed to experience a dataset containing features where each emaples is associated with a **label** (or **target**).
#
# **Unsupervised learning** algorithms experience a dataset containing many features, then learn useful properties of the **structure of this dataset**.
#
# Many unsupervised learning algorithms perform tasks, like **clustering**, which consists of dividing the dataset into clusters of similar examples.
#
# In the context of deep learning, we usually want to learn the entire *probability distribution that generated a dataset*, whether explicitly as in density estimation or implicitly for tasks like synthesis or denoising. See, for example, https://medium.com/@faridadilazuarda29/probability-distribution-concepts-in-generative-adversarial-networks-gans-bf93cb22fb72

# %% [markdown]
# PICTURE

# %% [markdown]
# Roughly speaking, unsupervised learning involves observing several examples of a random vector ***X*** and attempting to implicitly or explicitly learn the probability distribution p(***x***), or some interesting properties of that distribution, while supervised learning involves observing several examples of a random vector ***x*** and associated value or vector ***y***, and learning to predict ***y*** from ***x***, usually by estimating p (***y***|***x***).
#
# However, unsupervised learning and supervised learning are not formally defined terms.
#
# The chain rule of probability states that for a vector ***x*** ∈ Rn, the joint distribution can be decomposed as

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This decomposition means that we can solve the ostensibly unsupervised problem of modeling p(***x***) by splitting it into n supervised learning problems.
#
# Alternatively, we can solve the supervised learning problem of learning p(***y***|***x***) by using traditional unsupervised learning technologies to learn the joint distribution p (***x***,***y***) and inferring

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Semi-supervised learning**
#
# in semisupervised learning, some examples include a supervision target but others do not. See https://towardsdatascience.com/a-friendly-intro-to-semi-supervised-learning-3783c0146744

# %% [markdown]
# **Weakly-supervised and multi-instance learning**
#
# In multi-instance learning, an entire collection of examples is labeled as containing or not containing an example of a class, but the individual members of the collection are not labeled.
#
# See https://nilg.ai/202105/an-introduction-to-multiple-instance-learning/
#
# https://arxiv.org/abs/1411.3128

# %% [markdown]
# **Active learning**
#
# See https://towardsdatascience.com/introduction-to-active-learning-117e0740d7cc

# %% [markdown]
# **Self-supervised learning**
#
# See https://www.baeldung.com/cs/ml-self-supervised-learning

# %% [markdown]
# **Reinforcement learning**
#
# RL algorithms do not just experience a fixed dataset, but interact with an environment, so there is a feedback loop between the learning system and its experiences. We ignore this paradigm here.
#
# For an overview see https://arxiv.org/abs/1701.07274

# %% [markdown]
# **Task**

# %% [markdown]
# Below is a list of some most frequent ML tasks (supervised and unsupervised):
#
# - Classification: one of the central tasks within the supervised learning paradigm
# - Classification with missing inputs
# - Regression
# - Transcription
# - Machine translation
# - Anomaly detection
# - Synthesis and sampling
# - Imputation of missing values
# - Denoising
# - Density estimation or probability mass function estimation

# %% [markdown]
# Within the supervised learning paradigm, we label many data points (examples), and let the ML algorithm come up with a function that maps from examples to **labels (categories)**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When *y* = *f(**x**)*, the model assigns an input described by vector identified by numeric code *y*. There are other variants of the classification task, for example, where *f* outputs a probability distribution over classes.
#
# This process is called **learning** or **training**.
#
# The crucial point is that the *learned function is able to label previously unseen examples* correctly with a certain probability.
#
# This is the idea of **generalization**.
#
# We call the space of all possible functions the **hypothesis space**. A common hypothesis space for ML algorithms is that of **high-dimensional linear functions** of the type *f(x)* = *Wx* + *b* where *X* represents input vectors (e.g. pixels from an image), *W* is a weights (**parameters**) matrix and *b* is the bias (also a parameter).
#
# While the iput vectors (features) are fixed, parameters are learnable. The goal of a ML algorithm is to adjust parameters to map from ***x*** to *f(x)* in a desired form. Many ML algorithms are able to represent **non-linear** functions.

# %% [markdown]
# **Performance measure**
#
# For tasks such as classification, classification with missing inputs, and transcription, we often measure the **accuracy** of the model.
#
# Accuracy is just the *proportion of examples for which the model produces the correct output*.
#
# We can obtain equivalent information by measuring the **error rate** which is the proportion of examples for which the model produces an incorrect output.
#
# We often refer to the error rate as the expected 0-1 **loss**. The 0-1 loss on a particular example is 0 if it is correctly classified and 1 if it is not.
#
# For tasks such as density estimation, it does not make sense to measure accuracy, error rate, or any other kind of 0-1 loss.
#
# Instead, we must use a different performance metric that gives the model a continuous-valued score for each example. The most common approach is to report the **average log-probability** the model assigns to some examples.
#
# We evaluate performance measures using a **test set** of data that is separate from the data used for training the ML model.

# %% [markdown]
# **Choosing a performance measure**
#
# It is often difficult to choose a performance measure that corresponds well to the desired behavior of the system.
#
# For example, when performing a transcription task, should we measure the accuracy of the system at transcribing entire sequences, or should we use a more fine-grained performance measure that gives partial credit for getting some elements of the sequence correct?
#
# When performing a regression task, should we penalize the system more if it frequently makes medium-sized mistakes or if it rarely makes very large mistakes?
#
# In other cases, we know what quantity we would ideally like to measure, but measuring it is impractical. For example, this arises frequently in the context of density estimation. Many of the best probabilistic models represent probability distributions only implicitly.
#
# Computing the actual probability value assigned to a specific point in space in many such models is intractable. In these cases, one must design an alternative criterion that still corresponds to the design objectives, or design a good approximation to the desired criterion.

# %% [markdown]
# **Training/optimization**
# 		- loss function L(y,y-hat) measures the difference between the true label y and the predicted y-hat; loss is zero when the prediction is perfect
# 		- W and b (model parameters, theta) are tuned in order to minimize the loss function over the training examples: per-intance loss is averaged over all training examples
# 		- training examples are fixed; parameters are tunable
# 		- loss can be calculated using any function which maps two vectors to a scalar, however, in practice loss functions are chosen with easily computable gradients: binary cross-entrory loss (logistic loss), categorical cross-entrory loss (negative log likelihood)

# %% [markdown]
# **Validation during training**
#
# To create a test set, we subdivide the data usually in a 80/20% train-test split. In most cases it's a good idea to split randomly, but for time-dependent examples it might be important to have specific exaples in the training set.
#
# When you keep on re-training the ML model it's better to have a three way train-**validation/development**-test split (80/10/10%).
#
# Another possibility is to use leave-one-out or **k-fold cross-validation** which is more costly and is performed in cases when there are only few training examples.

# %% [markdown]
# PICTURE

# %% [markdown]
# **Relation between training and test error**
#
# During training of a ML model, we have access to the **training set**, we can compute some error measure on the training set called the **training error**, and we reduce this training error.
#
# So far, what we have described is simply an *optimization problem*. What separates machine learning from optimization is generalization error, also called the **test error**, to be low as well.
#
# The generalization error is defined as the expected value of the error on a new input. Here the expectation is taken across different possible inputs, drawn from the distribution of inputs we expect the system to encounter in practice.

# %% [markdown]
# **Data generating process**
#
# How can we affect performance on the test set when we get to observe only the training set? We rely on the assumptions of the **statistical learning theory**.
#
# We assume that the train and test data are generated by a probability distribution over datasets called the **data generating process**.
#
# Specifically, we assume that the examples in each dataset are independent from each other, and that the train set and test set are identically distributed, drawn from the same probability distribution.
#
# This assumption allows us to describe the data generating process with a probability distribution over a single example. We call that shared underlying distribution the **data generating distribution**, denoted *p*data.
#
# Therefore, the expected training error of a randomly selected model is equal to the expected test error of that model.

# %% [markdown]
# **Overfitting and Underfitting**
#
# When we train a ML model, we do not fix the parameters ahead of time, then sample both datasets. We sample the training set, then use it to choose the parameters to reduce training set error, then sample the test set.
#
# Under this process, the expected test error is greater than or equal to the expected value of training error.
#
# The factors determining how well a machine learning algorithm will perform are its ability to:
#   - Make the training error small.
#   - Make the gap between training and test error small.
#
# These two factors correspond to the two central challenges in machine learning: **underfitting** and **overfitting**.
#
# Underfitting occurs when the model is not able to obtain a sufficiently low error value on the training set. Overfitting occurs when the gap between the training error and test error is too large.
#
# We must remember that while simpler functions are more likely to generalize (to have a small gap between training and test error) we must still choose a sufficiently complex hypothesis to achieve low training error.

# %% [markdown]
# **Capacity**
#
# We can control whether a model is more likely to overfit or underfit by altering its **capacity**. Informally, a model’s capacity is its ability to fit a wide variety of functions.
#
# Models with low capacity may struggle to fit the training set. Models with high capacity can overfit by memorizing properties of the training set that do not serve them well on the test set.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Hypothesis space**
#
# One way to control the capacity of a learning algorithm is by choosing its **hypothesis space**, the set of functions that the learning algorithm is allowed to select as being the solution.
#
# By giving certain examples to the ML model and using a certain learning algorithm we are restricting the hypothesis space. This is the idea of **inductive bias**.
#
# For example, the linear regression algorithm has the set of all linear functions of its input as its hypothesis space. We can generalize linear regression to include polynomials, rather than just linear functions, in its hypothesis space. Doing so increases the model’s capacity.
#
# ML algorithms will generally perform best when their capacity is appropriate for the true complexity of the task they need to perform and the amount of training data they are provided with.
#
#  Models with insufficient capacity are unable to solve complex tasks. Models with high capacity can solve complex tasks, but when their capacity is higher than needed to solve the present task they may overfit.

# %% [markdown]
# **Representational and effective capacity**
#
# The model specifies which family of functions the learning algorithm can choose from when varying the parameters in order to reduce a training objective. This is called the **representational capacity** of the model.
#
# Additional limitations, such as the imperfection of the optimization algorithm, mean that the learning algorithm’s **effective capacity** may be less that the representational capacity of the model family.

# %% [markdown]
# **Vapnik-Chervonenkis dimension (VC dimension)**
#
# Statistical learning theory provides various means of quantifying model capacity. Among these, the most well-known is the Vapnik-Chervonenkis dimension which measures the capacity of a binary classifier.
#
# The VC dimension is defined as being the largest possible value of *m* for which there exists a training set of *m* different ***x*** points that the classifier can label arbitrarily.
#
# The most important results in statistical learning theory show that the discrepancy between training error and generalization error is bounded from above by a quantity that grows as the model capacity grows but shrinks as the number of training examples increases. See https://courses.engr.illinois.edu/ece544na/fa2014/vapnik71.pdf

# %% [markdown]
# **VC dimension in deep learning**
#
# These bounds provide intellectual justification that machine learning algorithms can work, but they are rarely used in practice when working with deep learning algorithms.
#
# This is in part because the bounds are often quite loose and in part because it can be quite difficult to determine the capacity of deep learning algorithms.
#
# The problem of determining the capacity of a deep learning model is especially difficult because the effective capacity is limited by the capabilities of the optimization algorithm, and we have little theoretical understanding of the very general non-convex optimization problems involved in deep learning.

# %% [markdown]
# **Relation between capacity and error**
#
# Typically, training error decreases until it asymptotes to the minimum possible error value as model capacity increases (assuming the error measure has a minimum value). Typically, generalization error has a U-shaped curve as a function of model capacity.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Parametric vs non-parametric models**
#
# A simple parametric model is linear regression. Parametric models learn a function described by a parametric vestor whose size is finite and fixed before any data is observed.
#
# Non-parametric models don't have such limitations such that we can reach the most extreme case of arbitrarily high capacity with them.
#
# Sometimes, non-parametric models are just theoretical abstractions (such as an algorithm that searches over all possible probability distributions) that cannot be implemented in practice.
#
# However, we can also design practical non-parametric models by making their complexity a function of the training set size. One example of such an algorithm is **nearest neighbor regression**.
#
# Unlike linear regression, which has a fixed-length vector of weights, the nearest neighbor regression model simply stores the point ***X*** and ***y*** from the training set.
#
# When asked to classify a test point ***x***, the model looks up the nearest entry in the training set and returns the associated regression target.
#
# Finally, we can also create a non-parametric learning algorithm by wrapping a parametric learning algorithm inside another algorithm that increases the number of parameters as needed.
#
# For example, we could imagine an outer loop of learning that changes the degree of the polynomial learned by linear regression on top of a polynomial expansion of the input.

# %% [markdown]
# **Capacity and dataset size**
#
# The ideal model is an **oracle** that simply knows the true probability distribution that generates the data. The error incurred by an oracle making predictions from the true distribution p(***x***,***y***) is called the **Bayes error**.
#
# In practice, we use the **human error** level as a proxy for the Bayes error.
#
# Training and generalization error vary as the size of the training set varies. Expected generalization error can never increase as the number of training examples increases.
#
# For non-parametric models, more data yields better generalization until the best possible error is achieved. Any fixed parametric model with less than optimal capacity will asymptote to an error value that exceeds the Bayes error.
#
# We 1) constructed a synthetic regression problem based on adding a moderate amount of noise to a degree-5 polynomial, 2) generated a single test set, and then 3) generated several different sizes of training set.
#
# For each size, we generated 40 different training sets in order to plot error bars showing 95 percent confidence intervals.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The MSE on the training and test set for two different models: a quadratic model, and a model with degree chosen to minimize the test error. Both are fit in closed form.
#
# For the quadratic model, the training error increases as the size of the training set increases. This is because larger datasets are harder to fit. Simultaneously, the test error decreases, because fewer incorrect hypotheses are consistent with the training data. The quadratic model does not have enough capacity to solve the task, so its test error asymptotes to a high value.
#
# The test error at optimal capacity asymptotes to the Bayes error. The training error can fall below the Bayes error, due to the ability of the training algorithm to memorize specific instances of the training set.
#
# As the training size increases to infinity, the training error of any fixed-capacity model (here, the quadratic model) must rise to at least the Bayes error.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As the training set size increases, the optimal capacity (shown here as the degree of the optimal polynomial regressor) increases. The optimal capacity plateaus after reaching sufficient complexity to solve the task.

# %% [markdown]
# **No free lunch theorem**
#
# Learning theory claims that a ML algorithm can generalize well from a finite training set of examples which seems to contradict some basic principles of logic.
#
# To logically infer a rule describing every member of a set, one must have information about every member of that set.
#
# In part, ML avoids this problem by offering only **probabilistic** rules, rather than the entirely certain rules used in purely logical reasoning.
#
# However, the **no free lunch theorem** (see https://psycnet.apa.org/record/1997-07562-001) states that, averaged over all possible data generating distributions, every classification algorithm has the same error rate when classifying previously unobserved points.
#
# In other words, in some sense, no machine learning algorithm is universally any better than any other. The most sophisticated algorithm has the same average performance (over all possible tasks) as merely predicting that every point belongs to the same class.
#
# Fortunately, these results hold only when we average over all possible data generating distributions. If we make assumptions about the kinds of probability distributions we encounter in real-world applications, then we can design learning algorithms that perform well on these distributions.
#
# This means that the goal of machine learning research is not to seek a universal learning algorithm or the absolute best learning algorithm. Instead, our goal is to understand what kinds of distributions are relevant to the “real world” that an AI agent experiences, and what kinds of machine learning algorithms perform well on data drawn from the kinds of data generating distributions we care about.

# %% [markdown]
# **Regularization**
#
# behavior of our algorithm is strongly affected not just by how large we make the set of functions allowed in its hypothesis space, but by the specific identity of those functions.
#
# We can also give a learning algorithm a preference for one solution in its hypothesis space to another.
#
# For example, we can modify the training criterion for linear regression to include weight decay p. 119

# %% [markdown]
# **Regularization**
# - tuning may result in overfitting the training data
# - regularization term (hyperparameter) lambdaR(theta) is added  to the loss to prevent overfitting
# - controlling the complexity of the learned parameters
# - the goal is to choose parameters which combine low loss and low complexity
# - L2 regularization: weight decay - punisches bigger weights/parameters more strongly
# - L1 regukarization: lasso - punishes all weights/parameters equally
# - droupout

# %% [markdown]
# **Hyper parameters**

# %% [markdown]
# **Point estimation**

# %% [markdown]
# **Bias**

# %% [markdown]
# **Variance**

# %% [markdown]
# **Maximum likelihood estimation**
#
# - https://machinelearningmastery.com/what-is-maximum-likelihood-estimation-in-machine-learning/
# - https://towardsdatascience.com/a-gentle-introduction-to-maximum-likelihood-estimation-9fbff27ea12f

# %% [markdown]
# **Maximum A posteriori (MAP) estimation**

# %% [markdown]
# - https://towardsdatascience.com/a-gentle-introduction-to-maximum-likelihood-estimation-and-maximum-a-posteriori-estimation-d7c318f9d22d

# %% [markdown]
# # Overview of classic algorithms

# %% [markdown]
# - Linear Discriminant Analysis
# - t-SNE (T-distributed Stochastic Neighbor Embedding)
# - MDS and PCoA
# - EM (expectation-maximization) https://en.wikipedia.org/wiki/Expectation%E2%80%93maximization_algorithm
# - Gaussian Naive Bayes
#
# - regression trees
# - random forests
# - gradient descent
# - AdaBoost
# - Gradient boost
# - XGBoost
# - Bayesian networks (Propabalistic graphical models)
# - Hidden Markov Models

# %% [markdown]
# **Propabalistic supervised learning**

# %% [markdown]
# https://stanford.edu/~shervine/teaching/cs-229/cheatsheet-supervised-learning

# %% [markdown]
# https://github.com/afshinea/stanford-cs-229-machine-learning/blob/master/en/cheatsheet-supervised-learning.pdf

# %% [markdown]
# *Linear regression*

# %% [markdown]
# *Logistic regression* p. 140
#
# - the output of a linear function is a scalar
# - we can transform the linear output from the function into a binary classification [0,1] by transforming it using a sigmoid function
# - sigmoid(x) = 1/1 + e^-Wx + b
# - with 0 being mapped to 0.5, this can be interpreted as probability/classifier's confidence about category/class membership of a particular example
# - in the context of neural networks we speak about activation functions
# - using a loss function, we can compute the difference between the predicted and the expected probability of a label/category and make the network learn

# %% [markdown]
# **Multi-class classification**
# 		- the output of a liner function is passed to the soft-max function
# 		- softmax(x) = e^x/sigma e^x
# 		- soft-max transformation forces the predicted values (y-hat) to be positive and to sum to 1, making them interpretable as a probability distribution
# 		- in the context of neural networks, softmax is applied at the output layer for multi-class classification

# %% [markdown]
# **Support vector machines** p. 141

# %% [markdown]
# **Non-parametric algorithms** p. 143
#
# *k-nearest neighbors*
#
# *Desicion trees* p. 145

# %% [markdown]
# **Unsupervised learning**
#
# *Principal Component Analysis (with Python)* p. 147
# *k-Means clustering* p. 150

# %% [markdown]
# # Motivation for Deep Learning

# %% [markdown]
# **Curse of dimensionality** p. 155

# %% [markdown]
# **Local Constancy and Smoothness Regularization**

# %% [markdown]
# **Manifold learning**
